# %% [markdown]
# # pybnafar Quickstart
#
# This notebook demonstrates how to use the `pybnafar` SDK to analyze pharmaceutical stock data from the Brazilian SUS.

# %%
from pybnafar import Bnafar
import pandas as pd

# Initialize workspace
bn = Bnafar(workspace='bnafar_example')

# Note: In a real environment, you would run bn.sync() first.
print("Bnafar SDK Initialized.")

# %% [markdown]
# ## 1. Loading Data
# We can load data using Hive pushdown for high performance.

# %%
# df = bn.load_optimized(ufs=['SP', 'MG'])
print("Ready to load optimized data partitions.")

# %% [markdown]
# ## 2. Running Analytics
# Let's detect medicine shortages.

# %%
# ruptures = bn.analytics.detect_real_ruptures(df)
# print(ruptures['confirmed_ruptures'].head())
